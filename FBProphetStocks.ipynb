# %% [markdown]
# <a href="https://colab.research.google.com/github/jlo458/Stock-Predictor/blob/main/FBProphetStocks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pystan~=2.14
# Out:
# ...
#   Using cached pystan-2.19.1.1.tar.gz (16.2 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pystan: filename=pystan-2.19.1.1-cp310-cp310-linux_x86_64.whl size=61975259 sha256=b44c45bb2103721154bc288d0a09d909755ce545220e4185708b780c96c8fd07
#   Stored in directory: /root/.cache/pip/wheels/3d/1c/94/4516243362eedbedad15ac4389691ee3bf2d45bec2639c9d8b
# Successfully built pystan
# ...

# %%
# !pip install prophet

# %%
import pandas as pd

data = pd.read_csv("Stock_Data.csv")

# %%
data = data[["Date","Close"]]

# %%
data.columns = ["ds","y"]

# %%
from prophet import Prophet

# %%
prophet = Prophet(daily_seasonality=True)
prophet.fit(data)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqme5un8v/cvio4k5c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpqme5un8v/rzbpwqst.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28154', 'data', 'file=/tmp/tmpqme5un8v/cvio4k5c.json', 'init=/tmp/tmpqme5un8v/rzbpwqst.json', 'output', 'file=/tmp/tmpqme5un8v/prophet_model93bmmm5f/prophet_model-20240605222032.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:20:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:20:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future_dates = prophet.make_future_dataframe(periods=365)
predictions = prophet.predict(future_dates)

# %%
from prophet.plot import plot_plotly

plot_plotly(prophet, predictions)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
